# %%
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression as LR

# %%
root_dir = '/Users/kessapassa/OneDrive/research_log/2018_Graduate/2D/'

# %%
dir_list = ['people10000', 'people20000', 'people30000']
seed_list = [str(123 + i) for i in range(3)]
csv_list = ['census', 'mobile']
times_list = [str(3600 * (i + 1)) for i in range(6)]

# %%
def create_base_dataframe():
    df = pd.DataFrame(columns=(['{0:02d}'.format(i*10) for i in range(6)]))
    return df

# %%
create_base_dataframe()
# Out:
# Empty DataFrame
# Columns: [00, 10, 20, 30, 40, 50]
# Index: []

# %%
# エリア番号を線形的な数から、iとjで回した数のようにする
def convert_area_to_contour(base, read):
    for r in np.asanyarray(read):
        area_id = int(r[1])
        row = str(area_id // 6)
        col = str(area_id % 6) + '0'
        base.loc[row, col] = r[2]
        
    return base

# %%
base = create_base_dataframe()

csv_array = {}
for _dir in dir_list:
    csv_array[_dir] = {}
    for _seed in seed_list:
        csv_array[_dir][_seed] = {}
        for _csv in csv_list:
            csv_array[_dir][_seed][_csv] = {}
            df = pd.read_csv(root_dir + _dir + 'seed' + _seed + '_' + _csv + '.csv',
                                                    index_col=0,
                                                    encoding='Shift_JISx0213')
            df['time'] = df['time'].apply(lambda x: str(int(x)))
            
            group_list = df.groupby(['time'])
            for _name, _group in group_list:
                df = convert_area_to_contour(base.copy(), _group.copy())
                df = df / df.sum().sum()
                csv_array[_dir][_seed][_csv][_name] = df

# %%
# なぜかこの時だけ21600がないので0で補間する
csv_array['people10000']['123']['census']['21600'] = pd.DataFrame(np.zeros((6, 6)), columns=(['{0:02d}'.format(i*10) for i in range(6)]))

# %%
csv_array['people10000']['123']['census']['21600']
# Out:
# <style  type="text/css" >
#     #T_dfcac462_0c32_11e9_8b9e_acde48001122row0_col0 {
#             background-color:  #0000ff;
#         }    #T_dfcac462_0c32_11e9_8b9e_acde48001122row0_col1 {
#             background-color:  #0000ff;
#         }    #T_dfcac462_0c32_11e9_8b9e_acde48001122row0_col2 {
#             background-color:  #0000ff;
#         }    #T_dfcac462_0c32_11e9_8b9e_acde48001122row0_col3 {
#             background-color:  #0000ff;
#         }    #T_dfcac462_0c32_11e9_8b9e_acde48001122row0_col4 {
#             background-color:  #0000ff;
#         }    #T_dfcac462_0c32_11e9_8b9e_acde48001122row0_col5 {
#             background-color:  #0000ff;
#         }    #T_dfcac462_0c32_11e9_8b9e_acde48001122row1_col0 {
#             background-color:  #0000ff;
#         }    #T_dfcac462_0c32_11e9_8b9e_acde48001122row1_col1 {
#             background-color:  #0000ff;
#         }    #T_dfcac462_0c32_11e9_8b9e_acde48001122row1_col2 {
#             background-color:  #0000ff;
# ...

# %%
# for _dir in dir_list:
#     for _seed in seed_list:
#         for _csv in ['census']:
#             for _times in times_list:
#                 csv_array[_dir][_seed][_csv][_times].to_csv('countor3d_per_times/'+_dir+'seed'+_seed+'_'+_csv+_times+'.csv')

# %%
import seaborn as sns
def add_color(df):
    cm = 'RdYlGn_r'
#     cm = sns.light_palette('RdYlGn_r', as_cmap=True)
    return df.style.background_gradient(cmap=cm)

# %%
people = 'people30000'
seed = '123'
csv = 'census'

# %%
time = '3600'
print(csv_array[people][seed][csv][time].sum().sum())
add_color(csv_array[people][seed][csv][time])
# Out:
# 1.0
# <style  type="text/css" >
#     #T_af3bcab6_0c33_11e9_8b9e_acde48001122row0_col0 {
#             background-color:  #016a38;
#         }    #T_af3bcab6_0c33_11e9_8b9e_acde48001122row0_col1 {
#             background-color:  #006837;
#         }    #T_af3bcab6_0c33_11e9_8b9e_acde48001122row0_col2 {
#             background-color:  #006837;
#         }    #T_af3bcab6_0c33_11e9_8b9e_acde48001122row0_col3 {
#             background-color:  #006837;
#         }    #T_af3bcab6_0c33_11e9_8b9e_acde48001122row0_col4 {
#             background-color:  #006837;
#         }    #T_af3bcab6_0c33_11e9_8b9e_acde48001122row0_col5 {
#             background-color:  #006837;
#         }    #T_af3bcab6_0c33_11e9_8b9e_acde48001122row1_col0 {
#             background-color:  #a50026;
#         }    #T_af3bcab6_0c33_11e9_8b9e_acde48001122row1_col1 {
#             background-color:  #026c39;
#         }    #T_af3bcab6_0c33_11e9_8b9e_acde48001122row1_col2 {
#             background-color:  #33a456;
# ...

# %%
time = '7200'
diff = str(int(time) - 3600)
add_color(csv_array[people][seed][csv][time] / csv_array[people][seed][csv][diff])
# Out:
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_c8facf92_0c33_11e9_8b9e_acde48001122row0_col0 {
#             background-color:  #a50026;
#         }    #T_c8facf92_0c33_11e9_8b9e_acde48001122row0_col1 {
#             background-color:  #98d368;
#         }    #T_c8facf92_0c33_11e9_8b9e_acde48001122row0_col2 {
#             background-color:  #c7e77f;
#         }    #T_c8facf92_0c33_11e9_8b9e_acde48001122row0_col3 {
#             background-color:  #006837;
#         }    #T_c8facf92_0c33_11e9_8b9e_acde48001122row0_col4 {
#             background-color:  #006837;
#         }    #T_c8facf92_0c33_11e9_8b9e_acde48001122row0_col5 {
#             background-color:  #006837;
#         }    #T_c8facf92_0c33_11e9_8b9e_acde48001122row1_col0 {
#             background-color:  #afdd70;
#         }    #T_c8facf92_0c33_11e9_8b9e_acde48001122row1_col1 {
# ...

# %%
time = '10800'
diff = str(int(time) - 3600)
add_color(csv_array[people][seed][csv][time] / csv_array[people][seed][csv][diff])
# Out:
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_c9cf3084_0c33_11e9_8b9e_acde48001122row0_col0 {
#             background-color:  #006837;
#         }    #T_c9cf3084_0c33_11e9_8b9e_acde48001122row0_col1 {
#             background-color:  #006837;
#         }    #T_c9cf3084_0c33_11e9_8b9e_acde48001122row0_col2 {
#             background-color:  #36a657;
#         }    #T_c9cf3084_0c33_11e9_8b9e_acde48001122row0_col3 {
#             background-color:  #006837;
#         }    #T_c9cf3084_0c33_11e9_8b9e_acde48001122row0_col4 {
#             background-color:  #006837;
#         }    #T_c9cf3084_0c33_11e9_8b9e_acde48001122row0_col5 {
#             background-color:  #006837;
#         }    #T_c9cf3084_0c33_11e9_8b9e_acde48001122row1_col0 {
#             background-color:  #f99153;
#         }    #T_c9cf3084_0c33_11e9_8b9e_acde48001122row1_col1 {
# ...

# %%
time = '14400'
diff = str(int(time) - 3600)
add_color(csv_array[people][seed][csv][time] / csv_array[people][seed][csv][diff])
# Out:
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/pandas/io/formats/style.py:906: RuntimeWarning: invalid value encountered in double_scalars
#   norm = colors.Normalize(s.min() - (rng * low),
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/pandas/io/formats/style.py:907: RuntimeWarning: invalid value encountered in double_scalars
#   s.max() + (rng * high))
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_cf058d32_0c33_11e9_8b9e_acde48001122row0_col0 {
#             background-color:  #006837;
#         }    #T_cf058d32_0c33_11e9_8b9e_acde48001122row0_col1 {
#             background-color:  #006837;
#         }    #T_cf058d32_0c33_11e9_8b9e_acde48001122row0_col2 {
#             background-color:  #006837;
#         }    #T_cf058d32_0c33_11e9_8b9e_acde48001122row0_col3 {
#             background-color:  #006837;
# ...

# %%
time = '18000'
diff = str(int(time) - 3600)
add_color(csv_array[people][seed][csv][time] / csv_array[people][seed][csv][diff])
# Out:
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/pandas/io/formats/style.py:906: RuntimeWarning: invalid value encountered in double_scalars
#   norm = colors.Normalize(s.min() - (rng * low),
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/pandas/io/formats/style.py:907: RuntimeWarning: invalid value encountered in double_scalars
#   s.max() + (rng * high))
# <style  type="text/css" >
#     #T_d6266686_0c33_11e9_8b9e_acde48001122row0_col0 {
#             background-color:  #006837;
#         }    #T_d6266686_0c33_11e9_8b9e_acde48001122row0_col1 {
#             background-color:  #006837;
#         }    #T_d6266686_0c33_11e9_8b9e_acde48001122row0_col2 {
#             background-color:  #006837;
#         }    #T_d6266686_0c33_11e9_8b9e_acde48001122row0_col3 {
#             background-color:  #006837;
# ...

# %%
time = '21600'
diff = str(int(time) - 3600)
add_color(csv_array[people][seed][csv][time] / csv_array[people][seed][csv][diff])
# Out:
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/pandas/io/formats/style.py:906: RuntimeWarning: invalid value encountered in double_scalars
#   norm = colors.Normalize(s.min() - (rng * low),
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/pandas/io/formats/style.py:907: RuntimeWarning: invalid value encountered in double_scalars
#   s.max() + (rng * high))
# /Users/kessapassa/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_edb93576_0c33_11e9_8b9e_acde48001122row0_col0 {
#             background-color:  #006837;
#         }    #T_edb93576_0c33_11e9_8b9e_acde48001122row0_col1 {
#             background-color:  #006837;
#         }    #T_edb93576_0c33_11e9_8b9e_acde48001122row0_col2 {
#             background-color:  #006837;
#         }    #T_edb93576_0c33_11e9_8b9e_acde48001122row0_col3 {
#             background-color:  #006837;
# ...
