# %%
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression as LR

# %%
root_dir = '/Users/kessapassa/OneDrive/research_log/2018_Graduate/2D/'

# %%
dir_list = ['people10000', 'people20000', 'people30000']
seed_list = [str(123 + i) for i in range(3)]
csv_list = ['census', 'mobile']

# %%
# エリア番号を線形的な数から、iとjで回した数のようにする
def convert_area_to_contour(area_id):
    area_id = int(area_id)
    contour_id = str(area_id // 6)
    contour_id += str(area_id % 6) + '0'

    return contour_id

# %%
csv_array = {}
for _dir in dir_list:
    csv_array[_dir] = {}
    for _seed in seed_list:
        csv_array[_dir][_seed] = {}
        for _csv in csv_list:
            df = pd.read_csv(root_dir + _dir + 'seed' + _seed + '_' + _csv + '.csv',
                                                    index_col=0,
                                                    encoding='Shift_JISx0213')
            csv_array[_dir][_seed][_csv] = df

# %%
def get_model(trainX, y):
    model = LR()
    model.fit(trainX, y)
    
    return model

# %%
model = None

pred_array = {}
for _dir in dir_list:
    pred_array[_dir] = {}
    for _seed in seed_list:
        pred_array[_dir][_seed] = {}
        for _csv in csv_list:
            pred_array[_dir][_seed][_csv] = {}

            # seed123だけを学習し、他はテストとする
            df = csv_array[_dir][_seed][_csv].copy()
            y = df['people']
            x = df[['time', 'area']]
            
            if _seed == '123':
                model = get_model(x, y)

            else:
                df['pred'] = model.predict(x)
                df['diff'] = df['people'] / df['pred']
                df = df.round(3)
                pred_array[_dir][_seed][_csv] = df

# %%
people = 'people20000'
seed = '125'
csv = 'census'

# %%
pred_array[people][seed][csv]
# Out:
#         time area  people     pred   diff
# 0     3600.0  000    16.0  179.054  0.089
# 1     3600.0  010    17.0  190.253  0.089
# 2     3600.0  020    40.0  201.452  0.199
# 3     3600.0  030     0.0  212.651  0.000
# 4     3600.0  040     0.0  223.850  0.000
# 5     3600.0  050     0.0  235.050  0.000
# 6     3600.0  100   853.0  291.045  2.931
# 7     3600.0  110    27.0  302.244  0.089
# 8     3600.0  120   323.0  313.444  1.030
# 9     3600.0  130   129.0  324.643  0.397
# 10    3600.0  140     0.0  335.842  0.000
# 11    3600.0  150     2.0  347.041  0.006
# 12    3600.0  200   138.0  403.037  0.342
# 13    3600.0  210   543.0  414.236  1.311
# 14    3600.0  220  2123.0  425.435  4.990
# 15    3600.0  230  1504.0  436.634  3.445
# 16    3600.0  240    47.0  447.833  0.105
# 17    3600.0  250    29.0  459.033  0.063
# 18    3600.0  300   118.0  515.028  0.229
# 19    3600.0  310   108.0  526.227  0.205
# 20    3600.0  320   416.0  537.427  0.774
# 21    3600.0  330  4717.0  548.626  8.598
# 22    3600.0  340  2457.0  559.825  4.389
# 23    3600.0  350    70.0  571.024  0.123
# 24    3600.0  400     3.0  627.020  0.005
# 25    3600.0  410   287.0  638.219  0.450
# 26    3600.0  420   359.0  649.418  0.553
# 27    3600.0  430  5002.0  660.617  7.572
# 28    3600.0  440  3697.0  671.816  5.503
# 29    3600.0  450     9.0  683.016  0.013
# ..       ...  ...     ...      ...    ...
# 186  21600.0  100     7.0  -80.645 -0.087
# 187  21600.0  110     0.0  -69.446 -0.000
# 188  21600.0  120     4.0  -58.247 -0.069
# 189  21600.0  130     0.0  -47.048 -0.000
# 190  21600.0  140     0.0  -35.849 -0.000
# 191  21600.0  150     0.0  -24.649 -0.000
# 192  21600.0  200     0.0   31.346  0.000
# 193  21600.0  210     4.0   42.545  0.094
# 194  21600.0  220    28.0   53.745  0.521
# 195  21600.0  230    39.0   64.944  0.601
# 196  21600.0  240     0.0   76.143  0.000
# 197  21600.0  250     0.0   87.342  0.000
# 198  21600.0  300     0.0  143.338  0.000
# 199  21600.0  310     0.0  154.537  0.000
# 200  21600.0  320     0.0  165.736  0.000
# 201  21600.0  330   517.0  176.935  2.922
# 202  21600.0  340   123.0  188.134  0.654
# 203  21600.0  350     0.0  199.334  0.000
# 204  21600.0  400     0.0  255.329  0.000
# 205  21600.0  410     0.0  266.528  0.000
# 206  21600.0  420     3.0  277.728  0.011
# 207  21600.0  430   190.0  288.927  0.658
# 208  21600.0  440   391.0  300.126  1.303
# 209  21600.0  450     0.0  311.325  0.000
# 210  21600.0  500     0.0  367.321  0.000
# 211  21600.0  510     0.0  378.520  0.000
# 212  21600.0  520     7.0  389.719  0.018
# 213  21600.0  530    22.0  400.918  0.055
# 214  21600.0  540    21.0  412.117  0.051
# 215  21600.0  550    18.0  423.317  0.043
#
# [216 rows x 5 columns]
