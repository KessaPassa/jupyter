# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression as LR

# %%
root_dir = '/Users/kessapassa/OneDrive/research_log/2018_Graduate/Origin/'

# %%
dir_list = ['2_8', '4_6', '6_4', '8_2']
seed_list = [str(123 + i) for i in range(3)]

csv_array = {}
for _dir in dir_list:
    csv_array[_dir] = {}
    for _seed in seed_list:
        csv_array[_dir][_seed] = pd.read_csv(root_dir+_dir+'seed'+_seed+'.csv', index_col=0, encoding='shift_jis')
        csv_array[_dir][_seed] = csv_array[_dir][_seed].loc[csv_array[_dir][_seed]['road'].str.contains('census')]

# %%
csv_array['6_4']['123']
# Out:
#            type   time                             road         x         y  \
# id
# 42580   Vehicle   3600                清水小坂線(census)(34) -1506.570 -3823.050
# 51751   Vehicle   3600                清水小坂線(census)(34)  -972.327 -3581.750
# 34748   Vehicle   3600                清水小坂線(census)(34) -1000.070 -3536.100
# 64770   Vehicle   3600                清水小坂線(census)(34)  -972.524 -3581.840
# 35071   Vehicle   3600                    清水小坂線(census) -2828.060 -4598.790
# 40702   Vehicle   3600               国道157号(census)(14) -1742.350 -2401.460
# 49268   Vehicle   3600                 靭本津幡線(census)(3) -7363.620 -5887.840
# 52831   Vehicle   3600       石川県道146号金沢停車場南線(census)(2) -2442.530 -1527.800
# 49816   Vehicle   3600       石川県道146号金沢停車場南線(census)(2) -2448.480 -1547.130
# 38199   Vehicle   3600              上安原昭和町線(census)(14) -2371.810 -1053.490
# 48112   Vehicle   3600            石川県道144号別所野町線(census) -2005.840 -3046.370
# 55420   Vehicle   3600                  金沢港線(census)(5) -2119.110 -1066.340
# 53764   Vehicle   3600                国道157号(census)(3) -2651.390 -3951.140
# 47411   Vehicle   3600                  金沢港線(census)(5) -2010.200 -1067.220
# 64066   Vehicle   3600       石川県道146号金沢停車場南線(census)(2) -2482.870 -1669.320
# 58402   Vehicle   3600       石川県道146号金沢停車場南線(census)(2) -2389.140 -1288.790
# 49093   Vehicle   3600                  金沢港線(census)(5) -2070.730 -1063.410
# 37988   Vehicle   3600             不万石通り;国道157号(census) -1667.500 -1613.730
# 46486   Vehicle   3600                国道157号(census)(3) -2637.770 -3922.070
# 65029   Vehicle   3600                国道157号(census)(3) -2125.610 -2911.580
# 47780   Vehicle   3600       石川県道146号金沢停車場南線(census)(2) -2433.290 -1494.630
# 34950   Vehicle   3600       石川県道146号金沢停車場南線(census)(2) -2495.730 -1713.060
# 36620   Vehicle   3600                国道157号(census)(3) -2166.680 -2970.350
# 46376   Vehicle   3600               国道157号(census)(11) -4643.790 -4906.040
# 38726   Vehicle   3600       石川県道146号金沢停車場南線(census)(2) -2461.800 -1595.940
# 51859   Vehicle   3600       石川県道146号金沢停車場南線(census)(2) -2417.960 -1315.450
# 46296   Vehicle   3600       石川県道146号金沢停車場南線(census)(2) -2448.830 -1527.950
# 65256   Vehicle   3600       石川県道146号金沢停車場南線(census)(2) -2418.890 -1325.070
# 48342   Vehicle   3600       石川県道25号金沢美川小松線(census)(10) -2570.330 -2798.590
# 55749   Vehicle   3600               国道157号(census)(14) -1937.760 -2687.520
# ...         ...    ...                              ...       ...       ...
# 61208   Vehicle  21600                    昭和大通り(census) -2173.090  -856.614
# 56459   Vehicle  21600                    昭和大通り(census) -2153.630  -818.897
# 49710   Vehicle  21600                  金沢港線(census)(6) -2467.500  -929.403
# 62051   Vehicle  21600       石川県道146号金沢停車場南線(census)(2) -2394.770 -1272.090
# 39506   Vehicle  21600                  金沢港線(census)(8) -1642.900 -1114.000
# 57279   Vehicle  21600               国道157号(census)(14) -1742.420 -2423.930
# 38637   Vehicle  21600       石川県道146号金沢停車場南線(census)(2) -2402.810 -1289.930
# 45213   Vehicle  21600   石川県道‘富屍県道10号金沢湯熔福光線(census)(2) -1334.000 -2407.000
# 49762   Vehicle  21600       石川県道146号金沢停車場南線(census)(2) -2418.450 -1391.130
# 58898   Vehicle  21600       石川県道146号金沢停車場南線(census)(2) -2415.960 -1364.470
# 63933   Vehicle  21600       石川県道146号金沢停車場南線(census)(2) -2420.430 -1344.960
# 41330   Vehicle  21600                  金沢港線(census)(8) -1630.690 -1111.600
# 40789   Vehicle  21600       石川県道146号金沢停車場南線(census)(2) -2413.510 -1333.350
# 44727   Vehicle  21600                    昭和大通り(census) -2150.210  -811.826
# 53317   Vehicle  21600             東大通り;金沢停車場北線(census) -1978.040  -558.427
# 34755   Vehicle  21600                   金沢停車場線(census) -1963.500  -723.796
# 45231   Vehicle  21600                  金沢港線(census)(8) -1633.110 -1117.090
# 50995   Vehicle  21600              上安原昭和町線(census)(14) -2335.840 -1058.650
# 51685   Vehicle  21600       石川県道146号金沢停車場南線(census)(2) -2424.930 -1395.720
# 58427   Vehicle  21600                  金沢港線(census)(8) -1625.960 -1120.250
# 56978   Vehicle  21600       石川県道146号金沢停車場南線(census)(2) -2421.030 -1352.720
# 41814   Vehicle  21600                  金沢港線(census)(3) -1619.640 -1135.710
# 59719   Vehicle  21600   石川県道‘富屍県道10号金沢湯熔福光線(census)(2) -1548.510 -2387.680
# 62206   Vehicle  21600                  金沢港線(census)(6) -2464.180  -924.409
# 46705   Vehicle  21600              上安原昭和町線(census)(14) -2365.080 -1054.460
# 40179   Vehicle  21600   石川県道‘富屍県道10号金沢湯熔福光線(census)(2) -1674.460 -2371.570
# 61947   Vehicle  21600                  金沢港線(census)(6) -2470.740  -920.167
# 34470   Vehicle  21600              上安原昭和町線(census)(14) -2387.210 -1051.280
# 39828   Vehicle  21600                  金沢港線(census)(3) -1606.360 -1155.970
# 62146   Vehicle  21600                  金沢港線(census)(6) -2474.050  -925.171
#
#        area  is_arrived
# id
# 42580    22        True
# 51751    22        True
# 34748    22        True
# 64770    22        True
# 35071    15        True
# 40702    21       False
# 49268    13       False
# 52831    27       False
# 49816    27       False
# 38199    27       False
# 48112    21       False
# 55420    27       False
# 53764    21       False
# 47411    27       False
# 64066    27       False
# 58402    27       False
# 49093    27       False
# 37988    28       False
# 46486    21       False
# 65029    21       False
# 47780    27       False
# 34950    27       False
# 36620    21       False
# 46376    14       False
# 38726    27       False
# 51859    27       False
# 46296    27       False
# 65256    27       False
# 48342    21       False
# 55749    21       False
# ...     ...         ...
# 61208    27       False
# 56459    27       False
# 49710    27       False
# 62051    27       False
# 39506    28       False
# 57279    21       False
# 38637    27       False
# 45213    22       False
# 49762    27       False
# 58898    27       False
# 63933    27       False
# 41330    28       False
# 40789    27       False
# 44727    27       False
# 53317    27       False
# 34755    27       False
# 45231    28       False
# 50995    27       False
# 51685    27       False
# 58427    28       False
# 56978    27       False
# 41814    28       False
# 59719    22       False
# 62206    27       False
# 46705    27       False
# 40179    22       False
# 61947    27       False
# 34470    27       False
# 39828    28       False
# 62146    27       False
#
# [4339 rows x 7 columns]
