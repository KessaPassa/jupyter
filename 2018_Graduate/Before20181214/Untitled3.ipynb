# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression as LR

# %%
root_dir = '/Users/kessapassa/OneDrive/research_log/2018_Graduate/Origin/'

# %%
dir_list = ['2_8', '4_6', '6_4', '8_2']
seed_list = [str(123 + i) for i in range(3)]

csv_array = {}
for _dir in dir_list:
    csv_array[_dir] = {}
    for _seed in seed_list:
        csv_array[_dir][_seed] = pd.read_csv(root_dir+_dir+'seed'+_seed+'.csv', index_col=0, encoding='shift_jis')
        csv_array[_dir][_seed] = csv_array[_dir][_seed].loc[csv_array[_dir][_seed]['road'].str.contains('road1112')]

# %%
for _dir in dir_list:
    for _seed in seed_list:
        print(csv_array[_dir][_seed]['road'])
        print('\n')
# Out:
# Series([], Name: road, dtype: object)
#
#
# Series([], Name: road, dtype: object)
#
#
# Series([], Name: road, dtype: object)
#
#
# id
# 39514     road11121
# 53803     road11121
# 39514     road11121
# 37914     road11121
# 63428     road11121
# 38093     road11121
# 63428     road11121
# 38093     road11121
# Name: road, dtype: object
#
#
# id
# 44322     road11121
# 65494     road11121
# 64393     road11121
# 42642     road11121
# 44322     road11121
# 65494     road11121
# 64393     road11121
# 42642     road11121
# 44322     road11121
# 62675     road11121
# 65494     road11121
# 64393     road11121
# 42642     road11121
# 44322     road11121
# 62675     road11121
# 65494     road11121
# 64393     road11121
# 42642     road11121
# 44322     road11121
# 62675     road11121
# 65494     road11121
# 64393     road11121
# 42642     road11121
# Name: road, dtype: object
#
#
# id
# 35704     road11121
# 36516     road11121
# 61491     road11121
# 35704     road11121
# ...
