# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression as LR

# %%
root_dir = '/Users/kessapassa/OneDrive/research_log/logs/'

# %%
df = pd.read_csv(root_dir+ '2_8' +'seed123.csv', 
                 names=['id', 'type', 'time', 'road', 'x', 'y'], 
                 encoding='shift_jis')

# %%
df.shape
# Out:
# (5559, 6)

# %%
overrap = df[df.duplicated(subset='id')].sort_values('id')

# %%
overrap.shape
# Out:
# (541, 6)

# %%
df.sort_values('id')
# Out:
#          id         type   time                          road         x  \
# 1108  34004   Pedestrian   3600                                -580.712
# 3968  34006   Pedestrian  14400                               -1522.360
# 3866  34010   Pedestrian  14400                               -1756.480
# 3058  34016   Pedestrian  10800                               -1584.800
# 2565  34023   Pedestrian  10800                               -1949.130
# 2101  34031   Pedestrian   7200                               -1716.610
# 2705  34034   Pedestrian  10800                               -3745.580
# 3735  34038   Pedestrian  14400                                1007.190
# 4100  34043   Pedestrian  14400                               -1427.560
# 295   34047      Vehicle   3600             国道157号(census)(3) -2439.140
# 4337  34051   Pedestrian  14400                               -3039.940
# 20    34053      Vehicle   3600            国道157号(census)(14) -1883.630
# ...

# %%
overrap.sort_values('id')
# Out:
#          id         type   time                         road          x  \
# 5390  34106   Pedestrian  18000                               -569.5280
# 4995  34147      Vehicle  18000                      road585 -1933.3000
# 4107  34182   Pedestrian  14400                                769.3480
# 5206  34257   Pedestrian  18000                              -1819.2800
# 3463  34272      Vehicle  14400            国道157号(census)(3) -2054.3400
# 4921  34272      Vehicle  18000                      road768 -1994.6100
# 1923  34273      Vehicle   7200                      road768 -1985.5900
# 3128  34307   Pedestrian  10800                              -4458.9500
# 4288  34414   Pedestrian  14400                              -3249.5000
# 3934  34420   Pedestrian  14400                              -2388.3900
# 1995  34515      Vehicle   7200                      road768 -1991.7500
# 2670  34515      Vehicle  10800                      road768 -1991.7400
# ...
